# %% [markdown]
# # This is heading 1

# %% [markdown]
# ## This is heading 2

# %% [markdown]
# ### This is heading 3

# %% [markdown]
# ## This is my program
# - hi
# - hello
# - namste
#    - kya hal chal

# %% [markdown]
# ## Fruits Names
# - Mango
# - Banana
# - Pineapple

# %% [markdown]
# - Asia
#      - India
#          - Rajasthan
#              - Jaipur

# %% [markdown]
# ## Shortcuts
# - B : cell generated below the active cell
# - dd : Delete the cell
# - A : Generate cell above
# - M : Make the cell as markdown ( use for html design , making reports )
# - R : Make the cell as raw data cell
# - Y : Make the cell as coding cell

# %% [markdown]
# ## Introduction to jupyter
# - open source software
# - Feerly available
# - Code editor
# - Easy to understand
# - Help to create reports, notes
# - Help to build models
# - Computation calculation
# - Complex calculation
# - Data Visualisation

# %%
import seaborn as sns

# %%
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# <img src='https://th.bing.com/th/id/OIP.9FfnimCbfyEGeRNva87c-QHaEK?w=247&h=180&c=7&r=0&o=7&dpr=1.5&pid=1.7&rm=3'>

# %% [markdown]
# <img src = 'https://www.jaisalmernews.com/wp-content/uploads/2024/06/242799-narendra-modi-takes-oath-as-prime-minister-of-india-for-third-consecutive-term-new-council6665d1fcd6aa9'>

# %% [markdown]
# <img src = "https://www.bing.com/th/id/OSK.p3kKCR1Y5LdKJC7dMiHDWRfVNLJYTCSrODo06fjn3Ak?w=224&h=200&c=8&rs=1&qlt=90&o=6&cb=thwsc4&dpr=1.5&pid=3.1&rm=2">

# %% [markdown]
# <img src = "https://th.bing.com/th/id/OIP.FV7TFXpWEwNgJ0i1yxpJVAHaEK?w=295&h=182&c=7&r=0&o=5&dpr=1.5&pid=1.7">

# %% [markdown]
# <img src = "https://th.bing.com/th/id/OIP.2IA27oFIDHTEoglqgg0_ugHaFj?w=232&h=180&c=7&r=0&o=7&dpr=1.5&pid=1.7&rm=3">

# %% [markdown]
# <img src = "https://th.bing.com/th/id/OIP.dw_5vIdImCRYyrfzQsAwdwHaHa?w=153&h=180&c=7&r=0&o=7&dpr=1.5&pid=1.7&rm=3">
