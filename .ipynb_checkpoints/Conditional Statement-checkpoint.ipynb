# %% [markdown]
# ## Conditional Statement :- make decisions on the basis of conditions
#     - if
#     - if else
#     - if elif
#     - if elif else
#     - Nested if

# %% [markdown]
#     - syntax
#         - if condition:
#                -block of code

# %%
if "rain":
    print("Bring Umbrella")
# Out:
# Bring Umbrella

# %%
if " ":        # consist of space so it makes condition True
    print("Hello Grras")
# Out:
# Hello Grras

# %%
if "":         # empty object >> condition are False
    print("Hello Grras")

# %% [markdown]
# ### Empty objects which makes condition False
#        - []
#        - ()
#        - None
#        - 0
#        - {}
#        - ""
#        - False

# %%
if []:
    print("This is my world")

# %%
if [()]:
    print("This is my world")
# Out:
# This is my world

# %%
if False:
    print("hi")

# %%
if []:     # Condition became False
    print("Hello")   # block of statement skip
    print("Bye")     # block of statement skip
print("kya hal chal")   # Execute bcz it is not part of if condition
print("Going for the lunch")   #  Execyte bcz it is not part of if condition
# Out:
# kya hal chal
# Going for the lunch

# %%
number = int(input("enter a number"))
if number == 2:
    print("This is valid number")
    print("You are corract")
print("Niklo yaha se")
print("Tum yaha aaye hi kyu")
# Out:
# enter a number 2
# This is valid number
# You are corract
# Niklo yaha se
# Tum yaha aaye hi kyu

# %%
num = int(input("Enter Your Number"))
if num == 4:
    print("It is four")
    print("It's is not four")
print("mujhe nahi pata")
print("Bye")
# Out:
# Enter Your Number 3
# mujhe nahi pata
# Bye

# %%
num = int(input("Enter Your Number"))
if num == 4:
    print("It is four")
    print("It's is not four")
print("mujhe nahi pata")
print("Bye")
# Out:
# Enter Your Number 4
# It is four
# It's is not four
# mujhe nahi pata
# Bye

# %%
a = 10
b = 40
   print(a + b)
# Out:
#   Cell In[11], line 3
#     print(a + b)
#     ^
# IndentationError: unexpected indent

# %%
a = 10 
b = 40
    print(a + b)   # indent error
print(f"Lo bhai output lelo {a + b}") # Due to error this line will execute
# Out:
#   Cell In[12], line 3
#     print(a + b)
#     ^
# IndentationError: unexpected indent

# %%
a = 10 
b = 40
print(a + b)  
print(f"Lo bhai output lelo {a + b}")
# Out:
# 50
# Lo bhai output lelo 50

# %%
a = 10 
b = 40
print(a + b)  
print(a/0)   # error
print(f"Lo bhai output lelo {a + b}")  # Line will not execute
# Out:
# 50
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 4
#       2 b = 40
#       3 print(a + b)
# ----> 4 print(a/0)
#       5 print(f"Lo bhai output lelo {a + b}")
#
# ZeroDivisionError: division by zero

# %% [markdown]
#     - if
#     - else

# %%
choice = int(input("1.Umbrella\n 2.No need"))
if choice == 1:
    print("I'm going with umbrella")
else:
    print("No problem")
# Out:
# 1.Umbrella
#  2.No need 1
# I'm going with umbrella

# %%
choice = int(input("1.Umbrella\n 2.No need"))
if choice == 1:
    print("I'm going with umbrella")
else:
    print("No problem")
# Out:
# 1.Umbrella
#  2.No need 5
# No problem

# %%
choice = int(input("1.Umbrella\n 2.No need"))
if choice <= 4:
    print("I'm going with umbrella")
else:
    print("No problem")
# Out:
# 1.Umbrella
#  2.No need 5
# No problem

# %%
print()

# %%
print(end = "")

# %%
print(end ="abc")
# Out:
# abc

# %%
print("kirti",end = "-")
print("rohan",end = "-")
# Out:
# kirti-rohan-

# %%
name = int(input("enter a no."))
if name <= 5:
    print(f"{name} is equal")
else:
    print(f"{name} is not equal")
# Out:
# enter a no. 5
# 5 is equal

# %%
print("kirti")
print("rohan")
# Out:
# kirti
# rohan

# %%
print("kirti",end = " ")
print("rohan",end = " ")
# Out:
# kirti rohan

# %%
print("\n")

# %%
print("\\n")
# Out:
# \n

# %%
ls = ["Nitin","Nikhil","Anil","Kapil"]
ls
# Out:
# ['Nitin', 'Nikhil', 'Anil', 'Kapil']

# %%
if ls.sort():
    print(f"{ls} I'm sorting the list")
else:
    print(f"{ls} not my job")
# Out:
# ['Anil', 'Kapil', 'Nikhil', 'Nitin'] not my job

# %%
ls = ["aman","lakshita","rohan","ayan"]
ls
# Out:
# ['aman', 'lakshita', 'rohan', 'ayan']

# %%
if ls.sort():
    print("I'm sorting the list")
else:
    print("This is not job")
# Out:
# This is not job

# %%
print(ls.sort())
# Out:
# None

# %%
ls.sort()
ls
# Out:
# ['aman', 'ayan', 'lakshita', 'rohan']

# %%
if ls.reverse():
    print("I'm sorting the list")
else:
    print("This is not job")
# Out:
# This is not job

# %%
print(ls.reverse())
# Out:
# None

# %%
if ls.pop():
    print("I'm sorting the list")
else:
    print("This is not job")
# Out:
# I'm sorting the list

# %%
print(ls.pop())
# Out:
# rohan

# %%
st = "Rohan"
if st.upper():
    print(("I'm Rohan"))
else:
    print("I'm not Rohan")
# Out:
# I'm Rohan

# %%
print(st.upper())
# Out:
# ROHAN

# %%
if ls[0] and ls.reverse():          # ls[0] >> aman  and ls.reverse() >> none == False
    print("Yes I'm list")           # skip
else:       # will execute now..........
    print("I'm not list")
    print("Bye")
print("GoodBye")
# Out:
# I'm not list
# Bye
# GoodBye

# %%
ls
# Out:
# ['aman', 'ayan']

# %%
ls[0]
# Out:
# 'aman'

# %%
ls.reverse()
ls
# Out:
# ['ayan', 'aman']

# %%
if ls[0] or ls[1]:
    print("I'm list")
else:
    print("I'm not list")
# Out:
# I'm list

# %%
if ls.pop() or ls[0] or ls[1]:
    print("I'm list")
else:
    print("I'm not list")
# Out:
# I'm list

# %%
if ls.pop() and ls[1] and ls.sort():
    print("I'm list")
else:
    print("I'm not list")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 if ls.pop() and ls[1] and ls.sort():
#       2     print("I'm list")
#       3 else:
#
# IndexError: list index out of range

# %%
ls
# Out:
# []

# %%
ls = ["Aman","rohan","aryan"]
ls
# Out:
# ['Aman', 'rohan', 'aryan']

# %%
if ls.pop():
    print("I'm popping")
else:
    print("I'm not popping")
ls
# Out:
# I'm popping
# ['Aman', 'rohan']

# %%
if ls.pop():
    print("I'm popping")
else:
    print("I'm not popping")
ls
# Out:
# I'm popping
# ['Aman']

# %%
if ls.pop():
    print("I'm popping")
else:
    print("I'm not popping")
ls
# Out:
# I'm popping
# []

# %%
ls = ["meenakshi","abhishek","bhavesh","keshav"]
ls
# Out:
# ['meenakshi', 'abhishek', 'bhavesh', 'keshav']

# %%
if ls.pop() and ls[0].isupper() or ls[2].islower():
    print("I'm out of my mind")
else:
    print("I will have don't worry")
    print("ok Bye")
# Out:
# I'm out of my mind

# %%
ls.pop()
# Out:
# 'bhavesh'

# %%
ls[0].isupper()
# Out:
# False

# %%
ls[2].islower()
# Out:
# True

# %%
len(ls)
# Out:
# 1

# %%
if ls.pop() and ls[0].isupper() or ls[2].islower():
    print("I'm out of my mind")
else:
    print("I will have don't worry")
    print("ok Bye")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 if ls.pop() and ls[0].isupper() or ls[2].islower():
#       2     print("I'm out of my mind")
#       3 else:
#
# IndexError: list index out of range

# %%
ls.pop()
# Out:
# 'keshav'

# %%
ls = ["aman","rohan","shreyansh","vrinda","deep"]
ls
# Out:
# ['aman', 'rohan', 'shreyansh', 'vrinda', 'deep']

# %%
if ls:     # condition is True
    print(ls[-2])
else:
    print(ls)
print(ls)
# Out:
# vrinda
# ['aman', 'rohan', 'shreyansh', 'vrinda', 'deep']

# %%
if 0 and Ture:   # condition is False
    print(ls[-2])
else:
    print(ls)
print(ls)
# Out:
# ['aman', 'rohan', 'shreyansh', 'vrinda', 'deep']
# ['aman', 'rohan', 'shreyansh', 'vrinda', 'deep']

# %%
if 0:    # condition is False
    print(ls[-2])
else:
    print(ls)
print(ls)
# Out:
# ['aman', 'rohan', 'shreyansh', 'vrinda', 'deep']
# ['aman', 'rohan', 'shreyansh', 'vrinda', 'deep']

# %%
bool(0)
# Out:
# False

# %% [markdown]
#        - if
#        - elif
#        - else

# %%
ls
# Out:
# ['aman', 'rohan', 'shreyansh', 'vrinda', 'deep']

# %%
if "aman" in ls:          # condition became Ture
    print("Aman is in the list")    # Now all other parts skip
elif "rohan" in ls:
    print("Rohan is in the list")
else:
    print("No one is in list")
# Out:
# Aman is in the list

# %%
month_input = int(input("Enter Your Month Number"))
if month_input == 1:
    print("Jan")
elif month_input == 2:
    print("Fav")
elif month_input == 3:
    print("Mar")
elif month_input == 4:
    print("Apr")
elif month_input == 5:
    print("May")
elif month_input == 6:
    print("Jun")
elif month_input == 7:
    print("Jly")
elif month_input == 8:
    print("Aug")
elif month_input == 9:
    print("Sep")
elif month_input == 10:
    print("Oct")
elif month_input == 11:
    print("Nov")
elif month_input == 12:
    print("Dec")
else:
    print("Invalid input")
# Out:
# Enter Your Month Number 8
# Aug

# %%
user_input = int(input("Enter week Number"))
if user_input == 1:
    print("mon")
elif user_input == 2:
    print("tue")
elif user_input == 3:
    print("wed")
elif user_input == 4:
    print("thu")
elif user_input == 5:
    print("fri")
elif user_input == 6:
    print("sat")
elif user_input == 7:
    print("sun")
else:
    print("Invalid Input")
# Out:
# Enter week Number 4
# thu

# %%
user_input = int(input("Enter week Number"))
if user_input == 1:
    print("mon")
elif user_input == 2:
    print("tue")
elif user_input == 3:
    print("wed")
elif user_input == 4:
    print("thu")
elif user_input == 5:
    print("fri")
elif user_input == 6:
    print("sat")
elif user_input == 7:
    print("sun")
else:
    print("Invalid Input")
# Out:
# Enter week Number m
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 user_input = int(input("Enter week Number"))
#       2 if user_input == 1:
#       3     print("mon")
#
# ValueError: invalid literal for int() with base 10: 'm'

# %%
user_input = int(input("Enter week Number"))
if user_input == 1:
    print("mon")
elif user_input == 2:
    print("tue")
elif user_input == 3:
    print("wed")
elif user_input == 4:
    print("thu")
elif user_input == 5:
    print("fri")
elif user_input == 6:
    print("sat")
elif user_input == 7:
    print("sun")
else:
    print("Invalid Input")
# Out:
# Enter week Number 7
# sun

# %%
user_input = int(input("Enter week Number"))
if user_input == 1:
    print("mon")
elif user_input == 2:
    print("tue")
elif user_input == 3:
    print("wed")
elif user_input == 4:
    print("thu")
elif user_input == 5:
    print("fri")
elif user_input == 6:
    print("sat")
elif user_input == 7:
    print("sun")
else:
    print("Invalid Input")
# Out:
# Enter week Number 22
# Invalid Input

# %%
user_input = float(input("Enter week Number"))
if user_input == 1:
    print("mon")
elif user_input == 2:
    print("tue")
elif user_input == 3:
    print("wed")
elif user_input == 4:
    print("thu")
elif user_input == 5:
    print("fri")
elif user_input == 6:
    print("sat")
elif user_input == 7:
    print("sun")
else:
    print("Invalid Input")
# Out:
# Enter week Number 5
# fri

# %% [markdown]
# ## Single line if else

# %%
num = int(input("Enter Your Number"))
"even" if num % 2 == 0 else "odd"
# Out:
# Enter Your Number 6
# 'even'

# %%
age = int(input("Enter your age"))
"can vote" if age >= 18 else "can not vote"
# Out:
# Enter your age 19
# 'can vote'

# %%
a = 10 
b = 30
c = 80
a if (a > b and a > c) else (b if b > c else c)
# Out:
# 80

# %%
a = 90
b = 70
c = 10
a if (a > b and a > c) else (b if b > c else a)
# Out:
# 90

# %%
a = 10 
b = 30
c = 80
a if (a > b and a > c) else (b if b > c else c)
# Out:
# 80

# %%
print(c)
# Out:
# 80

# %%
max(10,30,80)
# Out:
# 80

# %%
min(10,30,80)
# Out:
# 10

# %%
sum([10,20])
# Out:
# 30

# %%
ls = [10,20,23,45,6,77,980]

# %%
sum(ls)
# Out:
# 1161

# %%
max(ls)
# Out:
# 980

# %%
min(ls)
# Out:
# 6

# %%
ls = [1,2,3,44,3,2,11,23,45,66,200,1,34]

# %%
ls
# Out:
# [1, 2, 3, 44, 3, 2, 11, 23, 45, 66, 200, 1, 34]

# %%
ls.sort()
ls
# Out:
# [1, 1, 2, 2, 3, 3, 11, 23, 34, 44, 45, 66, 200]

# %%
ls[-1]
# Out:
# 200

# %%
ls = [1,2,3,44,3,2,11,23,45,66,200,1,34]
ls
# Out:
# [1, 2, 3, 44, 3, 2, 11, 23, 45, 66, 200, 1, 34]

# %%
ls.sort()

# %%
ls
# Out:
# [1, 1, 2, 2, 3, 3, 11, 23, 34, 44, 45, 66, 200]

# %%
ls[-1]
# Out:
# 200

# %%
ls = [1,2,3,44,3,2,11,23,45,66,200,1,34]

# %%
ls.sort(reverse=True)

# %%
ls[-1]
# Out:
# 1

# %% [markdown]
# ## Nested if
#        - if inside a if

# %%
age = 18
if age >= 18:    # condition True
    if age >= 60:  # condition False
        print("You are a senior citizen") # skip 
    else:
        print("You are teenager")     # Execute
# Out:
# You are teenager

# %%
age = int(input("Enter your age"))
if age >=18:    # True
    print("you can vote")
if age <=18:    # True
    print("You can vote bcz you are equal to 18")
else:
    print("Age is out of range")
# Out:
# Enter your age 18
# you can vote
# You can vote bcz you are equal to 18

# %%
age = int(input("Enter your age"))
if age >=18:
    print("you can vote")
if age <=18:
    print("You can vote bcz you are equal to 18")
else:
    print("Age is out of range")
# Out:
# Enter your age 17
# You can vote bcz you are equal to 18

# %%
age = int(input("Enter your age"))
if age >=18:    # True
    print("you can vote")
if age <=18:     # False
    print("You can vote bcz you are equal to 18")
else:
    print("Age is out of range")  # Now else part will take place
# Out:
# Enter your age 20
# you can vote
# Age is out of range

# %%
money = int(input("Enter your money"))
if money > 2000:   # False
    print("Movie dekhne ja sakte ho")
    if money > 5000:
        print("movie ke sath ghumne bhi ja sakte ho")  # now skip
    else:
        print("sirf movie dekhne ja sakte ho")
else:
    print("paise kamao nalayko")    # Execute
# Out:
# Enter your money 500
# paise kamao nalayko

# %%
money = int(input("Enter your money"))
if money > 2000:   
    print("Movie dekhne ja sakte ho")
    if money > 5000:
        print("movie ke sath ghumne bhi ja sakte ho")  
    else:
        print("sirf movie dekhne ja sakte ho")
else:
    print("paise kamao nalayko")
# Out:
# Enter your money 5000
# Movie dekhne ja sakte ho
# sirf movie dekhne ja sakte ho

# %%
money = int(input("Enter your money"))
if money > 2000:   # True
    print("Movie dekhne ja sakte ho")    # Execute
    if money > 5000:
        print("movie ke sath ghumne bhi ja sakte ho")  
    else:    # skip
        print("sirf movie dekhne ja sakte ho")
else:
    print("paise kamao nalayko")    # skip
# Out:
# Enter your money 10000
# Movie dekhne ja sakte ho
# movie ke sath ghumne bhi ja sakte ho

# %%
physics = float(input("Ener the physics marks"))
chemistry = float(input("Enter the chemitry marks"))
biology = float(input("Enter the biology marks"))
mathematics = float(input("Enter the mathematics marks"))
computer = float(input("Enter the computer marks"))
total_marks = physics + chemistry + biology + mathematics + computer
percentage = total_marks/500*100
# Out:
# Ener the physics marks 55
# Enter the chemitry marks 33
# Enter the biology marks 76
# Enter the mathematics marks 89
# Enter the computer marks 86

# %%
percentage
# Out:
# 67.80000000000001

# %%
if percentage >= 90:
   print("grade A")
elif percentage >=80:
   print("grade B")
elif percentage >=70:
   print("grade C")
elif percentage >=60:
   print("grade D")
elif percentage >=50:
   print("grade E")
else:
 print("Better luck next time")
# Out:
# grade D

# %% [markdown]
#     - 18. Write a pyhton program to input electricity unit charges and calculate total electricity bill according to the given condition:
#            - For first 50 units Rs. 0.50/ unit
#            - For next 100 units Rs. 0.75/unit
#            - For next 100 units Rs. 1.20/unit
#            - For unit above 250 Rs.1.50/unit
#            - An additional surcharge of 20% is added to the bill

# %%
unit = float(input("Enter No. of unit"))
bill = 0
if unit <= 50:
    bill = unit * 0.50
elif unit <= 150:
    bill = (unit - 50) * 0.75 + 25
elif unit <= 250:
    bill = (unit - 150) * 1.20 + 100
elif unit <= 250:
    bill = (unit - 250) * 1.50 + 220
surcharge = bill * 0.20
Total_bill = bill + surcharge
print(f"your final bill is {Total_bill}")
# Out:
# Enter No. of unit 50
# your final bill is 30.0
