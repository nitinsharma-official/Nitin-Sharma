# %% [markdown]
# ## Dictionary
#     - Collection of key & values
#     - key should be unique
#     - Mutable
#     - No indexing
#     - Enclosed with curly brackets { }
#     - ordered 3.7

# %%
d = {}
type(d)
# Out:
# dict

# %%
st = {
    "Name" : "Nitin Sharma",
    "College" : "The ICFAI University",
    "Subject" : "Data Science",
    "Marks" : 99
}
print(st)
# Out:
# {'Name': 'Nitin Sharma', 'College': 'The ICFAI University', 'Subject': 'Data Science', 'Marks': 99}

# %%
st["Name"]
# Out:
# 'Nitin Sharma'

# %%
st["College"]
# Out:
# 'The ICFAI University'

# %%
st["Subject"]
# Out:
# 'Data Science'

# %%
st["Marks"]
# Out:
# 99

# %%
st["Name"] = "Kirti Sharma"

# %%
st
# Out:
# {'Name': 'Kirti Sharma',
#  'College': 'The ICFAI University',
#  'Subject': 'Data Science',
#  'Marks': 99}

# %%
student = {
    "Name" : "Nitin Sharma",
    "Address" : "Rajasthan",
    "Subject" : "Data Science",
    "Marks"  : 95
}

# %%
student
# Out:
# {'Name': 'Nitin Sharma',
#  'Address': 'Rajasthan',
#  'Subject': 'Data Science',
#  'Marks': 95}

# %%
student["Name"]        # fetching data using key because not use indexing
# Out:
# 'Nitin Sharma'

# %%
student["Address"]
# Out:
# 'Rajasthan'

# %%
student["Subject"]
# Out:
# 'Data Science'

# %%
student["Marks"]
# Out:
# 95

# %%
# modifying value
student["Marks"] = 98   # assing object

# %%
student
# Out:
# {'Name': 'Nitin Sharma',
#  'Address': 'Rajasthan',
#  'Subject': 'Data Science',
#  'Marks': 98}

# %%
[i for i in dir(dict)if not i.startswith("_")]
# Out:
# ['clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
student
# Out:
# {'Name': 'Nitin Sharma',
#  'Address': 'Rajasthan',
#  'Subject': 'Data Science',
#  'Marks': 98}

# %%
st
# Out:
# {'Name': 'Kirti Sharma',
#  'College': 'The ICFAI University',
#  'Subject': 'Data Science',
#  'Marks': 99}

# %%
st.get("College")
# Out:
# 'The ICFAI University'

# %%
st.get("Marks")
# Out:
# 99

# %%
## get 
student.get("Address")
# Out:
# 'Rajasthan'

# %%
student.get("mark")   # not giving error

# %%
student["mark"]  # give the error when key not exists
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 student["mark"]
#
# KeyError: 'mark'

# %%
student.get("Marks","not found")
# Out:
# 95

# %%
st.keys()
# Out:
# dict_keys(['Name', 'College', 'Subject', 'Marks'])

# %%
st.values()
# Out:
# dict_values(['Kirti Sharma', 'The ICFAI University', 'Data Science', 99])

# %%
st.items()
# Out:
# dict_items([('Name', 'Kirti Sharma'), ('College', 'The ICFAI University'), ('Subject', 'Data Science'), ('Marks', 99)])

# %%
st.popitem()
print(st)
# Out:
# {'Name': 'Kirti Sharma', 'College': 'The ICFAI University', 'Subject': 'Data Science'}

# %%
student.keys()
# Out:
# dict_keys(['Name', 'Address', 'Subject', 'Marks'])

# %%
student.values()
# Out:
# dict_values(['Nitin Sharma', 'Rajasthan', 'Data Science', 95])

# %%
student.items()
# Out:
# dict_items([('Name', 'Nitin Sharma'), ('Address', 'Rajasthan'), ('Subject', 'Data Science'), ('Marks', 95)])

# %%
student.popitem()   # return and remove last element of dictionary
# Out:
# ('Marks', 95)

# %%
student
# Out:
# {'Name': 'Nitin Sharma', 'Address': 'Rajasthan', 'Subject': 'Data Science'}

# %%
student.pop("Name")   # pass key -- return value
# Out:
# 'Nitin Sharma'

# %%
student
# Out:
# {'Address': 'Rajasthan', 'Subject': 'Data Science'}

# %%
subject = ["Python","java","c","c++","ruby","javascript","R"]
subject
# Out:
# ['Python', 'java', 'c', 'c++', 'ruby', 'javascript', 'R']

# %%
d = {}

# %%
lan = ["Python","English","Hindi","Java","SQL"]
lan
# Out:
# ['Python', 'English', 'Hindi', 'Java', 'SQL']

# %%
b = {}

# %%
b.fromkeys(lan,98)
# Out:
# {'Python': 98, 'English': 98, 'Hindi': 98, 'Java': 98, 'SQL': 98}

# %%
d.fromkeys(subject)
# Out:
# {'Python': None,
#  'java': None,
#  'c': None,
#  'c++': None,
#  'ruby': None,
#  'javascript': None,
#  'R': None}

# %%
{}.fromkeys(subject,99)
# Out:
# {'Python': 99,
#  'java': 99,
#  'c': 99,
#  'c++': 99,
#  'ruby': 99,
#  'javascript': 99,
#  'R': 99}

# %%
{}.fromkeys("Nitin")
# Out:
# {'N': None, 'i': None, 't': None, 'n': None}

# %%
{}.fromkeys("Nitin","Kirti")
# Out:
# {'N': 'Kirti', 'i': 'Kirti', 't': 'Kirti', 'n': 'Kirti'}

# %%
{}.fromkeys(["Python","java","js","ruby","sas"])
# Out:
# {'Python': None, 'java': None, 'js': None, 'ruby': None, 'sas': None}

# %%
a = "c"          # value has been stored
b = "python"
a+b
# Out:
# 'cpython'

# %%
"c" + "python"       # without storing
# Out:
# 'cpython'

# %%
student
# Out:
# {'Address': 'Rajasthan', 'Subject': 'Data Science'}

# %%
student.setdefault("Name","Nitin")
# Out:
# 'Nitin'

# %%
st.setdefault("Name","Nitin")
# Out:
# 'Kirti Sharma'

# %%
st
# Out:
# {'Name': 'Kirti Sharma',
#  'College': 'The ICFAI University',
#  'Subject': 'Data Science'}

# %%
student
# Out:
# {'Address': 'Rajasthan', 'Subject': 'Data Science', 'Name': 'Nitin'}

# %%
student.setdefault("Name","Nikhil") # because already name exist
# Out:
# 'Nitin'

# %%
student.setdefault("age",21)
# Out:
# 21

# %%
st
# Out:
# {'Name': 'Kirti Sharma',
#  'College': 'The ICFAI University',
#  'Subject': 'Data Science'}

# %%
fac = {
    "Name" : "Nitin Sharma",
    "Marks" : 97,
}

# %%
fac.update(st)

# %%
fac
# Out:
# {'Name': 'Nitin Sharma',
#  'Marks': 97,
#  'College': 'The ICFAI University',
#  'Subject': 'Data Science'}

# %%
st
# Out:
# {'Name': 'Nitin Sharma',
#  'College': 'The ICFAI University',
#  'Subject': 'Data Science',
#  'Marks': 97}

# %%
faculty = {
    "Name" : "Saurabh sharma",
    "Subject" : "Python",
    "Marks"  : 44
}

# %%
faculty
# Out:
# {'Name': 'Saurabh sharma', 'Subject': 'Python', 'Marks': 44}

# %%
student
# Out:
# {'Address': 'Rajasthan', 'Subject': 'Data Science', 'Name': 'Nitin', 'age': 21}

# %%
student.update(faculty)

# %%
student
# Out:
# {'Address': 'Rajasthan',
#  'Subject': 'Python',
#  'Name': 'Saurabh sharma',
#  'age': 21,
#  'Marks': 44}

# %%
s = {
    "salary" : 70000,
    "pincode" : 303012
}

# %%
s.update(student)

# %%
s
# Out:
# {'salary': 70000,
#  'pincode': 303012,
#  'Address': 'Rajasthan',
#  'Subject': 'Python',
#  'Name': 'Saurabh sharma',
#  'age': 21,
#  'Marks': 44}

# %%
a=s.copy()
a
# Out:
# {'salary': 70000,
#  'pincode': 303012,
#  'Address': 'Rajasthan',
#  'Subject': 'Python',
#  'Name': 'Saurabh sharma',
#  'age': 21,
#  'Marks': 44}

# %%
a.clear()
a
# Out:
# {}

# %%
s
# Out:
# {'salary': 70000,
#  'pincode': 303012,
#  'Address': 'Rajasthan',
#  'Subject': 'Python',
#  'Name': 'Saurabh sharma',
#  'age': 21,
#  'Marks': 44}

# %% [markdown]
# ## Nested Dictionary

# %%
dic = {
    "lan" :{
        "Name" : "Nitin Sharma",
        "Age" : 21,
        "Marks" : 99
    },
    "lan1" :{
        "Name" : "Rahul Sharma",
        "Age" : 20,
        "Marks" : 97
    }
}
(dic)
# Out:
# {'lan': {'Name': 'Nitin Sharma', 'Age': 21, 'Marks': 99},
#  'lan1': {'Name': 'Rahul Sharma', 'Age': 20, 'Marks': 97}}

# %%
dic
# Out:
# {'lan': {'Name': 'Nitin Sharma', 'Age': 21, 'Marks': 99},
#  'lan1': {'Name': 'Rahul Sharma', 'Age': 20, 'Marks': 97}}

# %%
len(dic)
# Out:
# 2

# %%
dic["lan"]["Marks"]
# Out:
# 99

# %%
dic["lan1"]["Age"]
# Out:
# 20

# %%
d = {
    "101" :{
        "Name" : "Nitin",
        "age" : 22,
        "score" : 99
    },
    "102" : {
      "Name" : "Nikhil",
      "age" : 21,
      "score" : 88
    }
}

# %%
d
# Out:
# {'101': {'Name': 'Nitin', 'age': 22, 'score': 99},
#  '102': {'Name': 'Nikhil', 'age': 21, 'score': 88}}

# %%
d["101"]["score"]
# Out:
# 99

# %%
d["102"]["age"]
# Out:
# 21

# %%
{'fsq_id': '50081e28e4b05eac5b27a1e9',
 'categories': [{'id': 13002,
   'name': 'Bakery',
   'short_name': 'Bakery',
   'plural_name': 'Bakeries',
   'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
    'suffix': 'jpeg'}},
  {'id': 13034,
   'name': 'Café',
   'short_name': 'Café',
   'plural_name': 'Cafés',
   'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
    'suffix': 'jpeg'}},
  {'id': 13065,
   'name': 'Restaurant',
   'short_name': 'Restaurant',
   'plural_name': 'Restaurants',
   'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
    'suffix': 'jpeg'}}],
 'chains': [],
 'closed_bucket': 'LikelyOpen',
 'distance': 1751,
 'geocodes': {'main': {'longitude': 75.794941}},
 'link': '/v3/places/50081e28e4b05eac5b27a1e9',
 'location': {'country': 'IN',
  'cross_street': '',
  'formatted_address': '941735, Rājasthān',
  'postcode': '941735',
  'region': 'Rājasthān'},
 'name': 'NIBS- The Chocolate Workshop',
 'related_places': {},
 'timezone': 'Asia/Kolkata'}
# Out:
# {'fsq_id': '50081e28e4b05eac5b27a1e9',
#  'categories': [{'id': 13002,
#    'name': 'Bakery',
#    'short_name': 'Bakery',
#    'plural_name': 'Bakeries',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#     'suffix': 'jpeg'}},
#   {'id': 13034,
#    'name': 'Café',
#    'short_name': 'Café',
#    'plural_name': 'Cafés',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#     'suffix': 'jpeg'}},
#   {'id': 13065,
#    'name': 'Restaurant',
#    'short_name': 'Restaurant',
#    'plural_name': 'Restaurants',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#     'suffix': 'jpeg'}}],
#  'chains': [],
#  'closed_bucket': 'LikelyOpen',
#  'distance': 1751,
#  'geocodes': {'main': {'longitude': 75.794941}},
#  'link': '/v3/places/50081e28e4b05eac5b27a1e9',
#  'location': {'country': 'IN',
#   'cross_street': '',
#   'formatted_address': '941735, Rājasthān',
#   'postcode': '941735',
# ...

# %% [markdown]
# ## fetch item
# - name
# - icon
# - change suffix png into jpeg 13034
# - find name from id 13034
# - timezone

# %%
data.keys()
# Out:
# dict_keys(['fsq_id', 'categories', 'chains', 'closed_bucket', 'distance', 'geocodes', 'link', 'location', 'name', 'related_places', 'timezone'])

# %%
data["categories"][0]["name"]   # id_13002
# Out:
# 'Bakery'

# %%
data["categories"][0]["icon"]
# Out:
# {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#  'suffix': 'jpeg'}

# %%
data["categories"][0]["icon"]["suffix"] = "jpeg"

# %%
data["categories"][0]["icon"]["suffix"]
# Out:
# 'jpeg'

# %%
data
# Out:
# {'fsq_id': '50081e28e4b05eac5b27a1e9',
#  'categories': [{'id': 13002,
#    'name': 'Bakery',
#    'short_name': 'Bakery',
#    'plural_name': 'Bakeries',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#     'suffix': 'jpeg'}},
#   {'id': 13034,
#    'name': 'Café',
#    'short_name': 'Café',
#    'plural_name': 'Cafés',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#     'suffix': 'jpeg'}},
#   {'id': 13065,
#    'name': 'Restaurant',
#    'short_name': 'Restaurant',
#    'plural_name': 'Restaurants',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#     'suffix': 'jpeg'}}],
#  'chains': [],
#  'closed_bucket': 'LikelyOpen',
#  'distance': 1751,
#  'geocodes': {'main': {'longitude': 75.794941}},
#  'link': '/v3/places/50081e28e4b05eac5b27a1e9',
#  'location': {'country': 'IN',
#   'cross_street': '',
#   'formatted_address': '941735, Rājasthān',
#   'postcode': '941735',
# ...

# %%
data.keys()
# Out:
# dict_keys(['fsq_id', 'categories', 'chains', 'closed_bucket', 'distance', 'geocodes', 'link', 'location', 'name', 'related_places', 'timezone'])

# %%
data["categories"][1]["name"] # id_13034
# Out:
# 'Café'

# %%
data["categories"][1]["icon"]["suffix"] = "jpeg"
data["categories"][1]["icon"]["suffix"]
# Out:
# 'jpeg'

# %%
data
# Out:
# {'fsq_id': '50081e28e4b05eac5b27a1e9',
#  'categories': [{'id': 13002,
#    'name': 'Bakery',
#    'short_name': 'Bakery',
#    'plural_name': 'Bakeries',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#     'suffix': 'jpeg'}},
#   {'id': 13034,
#    'name': 'Café',
#    'short_name': 'Café',
#    'plural_name': 'Cafés',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#     'suffix': 'jpeg'}},
#   {'id': 13065,
#    'name': 'Restaurant',
#    'short_name': 'Restaurant',
#    'plural_name': 'Restaurants',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#     'suffix': 'jpeg'}}],
#  'chains': [],
#  'closed_bucket': 'LikelyOpen',
#  'distance': 1751,
#  'geocodes': {'main': {'longitude': 75.794941}},
#  'link': '/v3/places/50081e28e4b05eac5b27a1e9',
#  'location': {'country': 'IN',
#   'cross_street': '',
#   'formatted_address': '941735, Rājasthān',
#   'postcode': '941735',
# ...

# %%
data["categories"][2]["name"] # id_13065
# Out:
# 'Restaurant'

# %%
data["categories"][2]["icon"]["suffix"] = "jpeg"
data["categories"][2]["icon"]["suffix"]
# Out:
# 'jpeg'

# %%
data.keys()
# Out:
# dict_keys(['fsq_id', 'categories', 'chains', 'closed_bucket', 'distance', 'geocodes', 'link', 'location', 'name', 'related_places', 'timezone'])

# %%
data["timezone"]
# Out:
# 'Asia/Kolkata'

# %%
data
# Out:
# {'fsq_id': '50081e28e4b05eac5b27a1e9',
#  'categories': [{'id': 13002,
#    'name': 'Bakery',
#    'short_name': 'Bakery',
#    'plural_name': 'Bakeries',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#     'suffix': 'jpeg'}},
#   {'id': 13034,
#    'name': 'Café',
#    'short_name': 'Café',
#    'plural_name': 'Cafés',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#     'suffix': 'jpeg'}},
#   {'id': 13065,
#    'name': 'Restaurant',
#    'short_name': 'Restaurant',
#    'plural_name': 'Restaurants',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#     'suffix': 'jpeg'}}],
#  'chains': [],
#  'closed_bucket': 'LikelyOpen',
#  'distance': 1751,
#  'geocodes': {'main': {'longitude': 75.794941}},
#  'link': '/v3/places/50081e28e4b05eac5b27a1e9',
#  'location': {'country': 'IN',
#   'cross_street': '',
#   'formatted_address': '941735, Rājasthān',
#   'postcode': '941735',
# ...
